# %%
# Import the necessary packages
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, chain
BASE_DIR = Path().resolve().parent

# %%
# Create a string and list to read in all files.
start_title = ["ashe_sims_"]
election_title = ["Asheboro BoE ", "Asheboro Council "]
demographics = ["Bachelors Degree", "Black", "High School Diploma", "Hispanic", "Some College", "White"]
end_title = ["_BT.csv", "_PL.csv", "_Cam.csv"]

# Find every possible combination, then join into list of strings
csv_list = list(product(start_title, election_title, demographics, end_title))
csv_titles = [[''.join(elem)] for elem in csv_list] # Source: https://stackoverflow.com/questions/72186008/python-join-strings-in-list-of-lists; https://stackoverflow.com/questions/11264684/flatten-list-of-lists
csv_titles = list(chain.from_iterable(csv_titles)) # Flatten into one list 
# Now we have a list of all the csvs we need to read-in and analyze!

# %%
num_winners_boe = 3 # Manually set this by race
num_winners_council = 3 # Manually set this by race
num_simulations_per_race = len(demographics) * len(end_title) # Total number of combinations

# %%
# Read in all the csvs into a list of pandas dataframes
df_list = []

for i in csv_titles:
    df_list.append(pd.read_csv(BASE_DIR / "Results" / "Elections" / "Asheboro Sims" / i))

# %%
df_list[0]
# Out:
#             Candidate Plurality Result STV Result Difference
# 0         Gidget Kidd             True       True      False
# 1       Gwen Williams            False      False      False
# 2    Melissa Calloway             True       True      False
# 3         Ryan Patton             True       True      False
# 4        Todd Dulaney            False      False      False
# ..                ...              ...        ...        ...
# 595     Gwen Williams             True       True      False
# 596  Melissa Calloway             True       True      False
# 597       Ryan Patton            False      False      False
# 598      Todd Dulaney            False      False      False
# 599               NaN              NaN        NaN        NaN
#
# [600 rows x 4 columns]

# %%
# Ranked Choice Voting Results

for i in range(len(df_list)):
    num_candidates = int(df_list[i]['Candidate'].isna().idxmax())
   
    df_list[i] = df_list[i].dropna().reset_index()
    grps = df_list[i].groupby(df_list[i].index // num_candidates)
    all_winners = []
    for _, dfg in grps:
        winners = dfg[dfg['STV Result'] == True]
        winners = winners['Candidate'] 
        all_winners.append(list(winners))

    all_winners = tuple(all_winners)

    counts = {}
    for j in all_winners:
        j = str(j)
        if j in counts:
            counts[j] += 1
        else:
            counts[j] = 1
    print("Most common winners in this", csv_titles[i], "simulation: ", max(counts, key=counts.get))
    print("This occured in", max(counts.values()), "iterations out of", len(all_winners))
# Out:
# Most common winners in this ashe_sims_Asheboro BoE Bachelors Degree_BT.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 90 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Bachelors Degree_PL.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 94 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Bachelors Degree_Cam.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 92 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Black_BT.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Black_PL.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Black_Cam.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE High School Diploma_BT.csv simulation:  ['Gwen Williams', 'Melissa Calloway', 'Ryan Patton']
# This occured in 30 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE High School Diploma_PL.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 55 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE High School Diploma_Cam.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 45 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Hispanic_BT.csv simulation:  ['Gidget Kidd', 'Gwen Williams', 'Melissa Calloway']
# This occured in 85 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Hispanic_PL.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 99 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Hispanic_Cam.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Some College_BT.csv simulation:  ['Gidget Kidd', 'Gwen Williams', 'Ryan Patton']
# This occured in 59 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Some College_PL.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 57 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE Some College_Cam.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 55 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE White_BT.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE White_PL.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro BoE White_Cam.csv simulation:  ['Gidget Kidd', 'Melissa Calloway', 'Ryan Patton']
# This occured in 98 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Bachelors Degree_BT.csv simulation:  ['Charles Swiers', 'Jane Hughes Redding', 'Joey Trogdon']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Bachelors Degree_PL.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 43 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Bachelors Degree_Cam.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 44 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Black_BT.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 71 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Black_PL.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 70 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Black_Cam.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 77 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council High School Diploma_BT.csv simulation:  ['Eddie Burks', 'Jane Hughes Redding', 'Joey Trogdon']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council High School Diploma_PL.csv simulation:  ['Charles Swiers', 'Jane Hughes Redding', 'Joey Trogdon']
# This occured in 36 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council High School Diploma_Cam.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 39 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Hispanic_BT.csv simulation:  ['Eddie Burks', 'Jane Hughes Redding', 'Joey Trogdon']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Hispanic_PL.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 48 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Hispanic_Cam.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 61 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Some College_BT.csv simulation:  ['Charles Swiers', 'Jane Hughes Redding', 'Joey Trogdon']
# This occured in 75 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Some College_PL.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 45 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council Some College_Cam.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 43 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council White_BT.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 100 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council White_PL.csv simulation:  ['Charles Swiers', 'Eddie Burks', 'Joey Trogdon']
# This occured in 44 iterations out of 100
# Most common winners in this ashe_sims_Asheboro Council White_Cam.csv simulation:  ['Eddie Burks', 'Jane Hughes Redding', 'Joey Trogdon']
# This occured in 40 iterations out of 100

# %%
# But how do we best visualize this?
# Right now, it's just a lotttt of output.
