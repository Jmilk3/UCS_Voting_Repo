# %%
# Import the necessary packages
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, chain
BASE_DIR = Path().resolve().parent

# %%
# Create a string and list to read in all files.
start_title = ["char_sims_"]
election_title = ["Charlotte Board of Education ", "Charlotte City Council ", "Charlotte Mayor "]
demographics = ["Black", "High School Diploma", "Hispanic", "Some College", "White"]
end_title = ["_BT.csv", "_PL.csv", "_Cam.csv"]

# Find every possible combination, then join into list of strings
csv_list = list(product(start_title, election_title, demographics, end_title))
csv_titles = [[''.join(elem)] for elem in csv_list] # Source: https://stackoverflow.com/questions/72186008/python-join-strings-in-list-of-lists; https://stackoverflow.com/questions/11264684/flatten-list-of-lists
csv_titles = list(chain.from_iterable(csv_titles)) # Flatten into one list 
# Now we have a list of all the csvs we need to read-in and analyze!

# %%
# Read in all the csvs into a list of pandas dataframes
df_list = []

for i in csv_titles:
    df_list.append(pd.read_csv(BASE_DIR / "Results" / "Elections" / "Charlotte Sims" / i))

# This code isn't currently running for Bachelor's Degree because of the difference between apostrophe and not. I just dropped it for now.

# %%
# Ranked Choice Voting Results

for i in range(len(df_list)):
    num_candidates = int(df_list[i]['Candidate'].isna().idxmax())
   
    df_list[i] = df_list[i].dropna().reset_index()
    grps = df_list[i].groupby(df_list[i].index // num_candidates)
    all_winners = []
    for _, dfg in grps:
        winners = dfg[dfg['STV Result'] == True]
        winners = winners['Candidate'] 
        all_winners.append(list(winners))

    all_winners = tuple(all_winners)

    counts = {}
    for j in all_winners:
        j = str(j)
        if j in counts:
            counts[j] += 1
        else:
            counts[j] = 1
    print("Most common winners in this", csv_titles[i], "simulation: ", max(counts, key=counts.get))
    print("This occured in", max(counts.values()), "iterations out of", len(all_winners))
# Out:
# Most common winners in this char_sims_Charlotte Board of Education Black_BT.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 94 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Black_PL.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 95 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Black_Cam.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 54 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education High School Diploma_BT.csv simulation:  ['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']
# This occured in 92 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education High School Diploma_PL.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 98 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education High School Diploma_Cam.csv simulation:  ['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']
# This occured in 55 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Hispanic_BT.csv simulation:  ['Annette Albright', 'Lenora Shipp', 'Shamaiye Haynes']
# This occured in 95 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Hispanic_PL.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 99 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Hispanic_Cam.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Some College_BT.csv simulation:  ['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']
# This occured in 90 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Some College_PL.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 94 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education Some College_Cam.csv simulation:  ['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']
# This occured in 70 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education White_BT.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 60 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education White_PL.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 94 iterations out of 100
# Most common winners in this char_sims_Charlotte Board of Education White_Cam.csv simulation:  ['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']
# This occured in 83 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Black_BT.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Black_PL.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Black_Cam.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council High School Diploma_BT.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council High School Diploma_PL.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council High School Diploma_Cam.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Hispanic_BT.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Hispanic_PL.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Hispanic_Cam.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Some College_BT.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Some College_PL.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council Some College_Cam.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council White_BT.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council White_PL.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte City Council White_Cam.csv simulation:  ['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Black_BT.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Black_PL.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Black_Cam.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor High School Diploma_BT.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor High School Diploma_PL.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor High School Diploma_Cam.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Hispanic_BT.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Hispanic_PL.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Hispanic_Cam.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Some College_BT.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Some College_PL.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor Some College_Cam.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor White_BT.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor White_PL.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
# Most common winners in this char_sims_Charlotte Mayor White_Cam.csv simulation:  ['Vi Alexander Lyles']
# This occured in 100 iterations out of 100
