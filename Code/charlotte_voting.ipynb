# %%
import pandas as pd
from pathlib import Path
BASE_DIR = Path().resolve().parent

charlotte_mayor = pd.read_csv(BASE_DIR / "Election_Data_Sheets" / "csv" / "results_pct_20231107.csv")

# %%
charlotte_mayor = charlotte_mayor.loc[charlotte_mayor['County'] == "MECKLENBURG"]

# %%
charlotte_mayor = charlotte_mayor.loc[charlotte_mayor['Contest Name'] == "CITY OF CHARLOTTE MAYOR"]

# %%
charlotte_mayor
# Out:
#             County Election Date     Precinct  Contest Group ID Contest Type  \
# 2903   MECKLENBURG       11/7/23            1                 1            C
# 2904   MECKLENBURG       11/7/23            1                 1            C
# 2905   MECKLENBURG       11/7/23            1                 1            C
# 2906   MECKLENBURG       11/7/23            1                 1            C
# 2907   MECKLENBURG       11/7/23            1                 1            C
# ...            ...           ...          ...               ...          ...
# 31214  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31215  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31216  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31217  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31218  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
#
# ...

# %%
BASE_DIR_DIR = Path().resolve().parent.parent

# %%
charlotte_vr = pd.read_csv(BASE_DIR_DIR / "charlotte_voter_registration.txt", encoding = 'latin-1', sep='\t')

# %%
charlotte_voter_hist = pd.read_csv(BASE_DIR_DIR / "charlotte_voter_hist.txt", encoding = 'latin-1', sep='\t')

# %%
charlotte_voter_hist = charlotte_voter_hist.loc[charlotte_voter_hist['election_lbl'] == "11/07/2023"]

# %%
charlotte_voter_hist
# Out:
#          county_id  county_desc  voter_reg_num election_lbl  \
# 19              60  MECKLENBURG      999856264   11/07/2023
# 26              60  MECKLENBURG      999870499   11/07/2023
# 36              60  MECKLENBURG     1000129811   11/07/2023
# 45              60  MECKLENBURG     1000149480   11/07/2023
# 97              60  MECKLENBURG      999892947   11/07/2023
# ...            ...          ...            ...          ...
# 3877855         60  MECKLENBURG     1000797433   11/07/2023
# 3877865         60  MECKLENBURG     1000797320   11/07/2023
# 3877898         60  MECKLENBURG     1000470410   11/07/2023
# 3878018         60  MECKLENBURG     1000747424   11/07/2023
# 3878092         60  MECKLENBURG     1000279263   11/07/2023
#
#                 election_desc           voting_method voted_party_cd  \
# 19       11/07/2023 MUNICIPAL        ABSENTEE ONESTOP            DEM
# 26       11/07/2023 MUNICIPAL  ELECTION DAY IN-PERSON            DEM
# ...

# %%
charlotte_vr
# Out:
#         county_id  county_desc  voter_reg_num       ncid last_name first_name  \
# 0              60  MECKLENBURG     1000747554  CW1441960         A     CARMEN
# 1              60  MECKLENBURG     1000374126  CW1170669         A       CHUA
# 2              60  MECKLENBURG     1000363600  CW1164524         A        HAI
# 3              60  MECKLENBURG     1000166591  CW1016763         A       HUOI
# 4              60  MECKLENBURG     1000368416  CW1167483         A        LAI
# ...           ...          ...            ...        ...       ...        ...
# 946567         60  MECKLENBURG     1000436286  CW1218925   ZYWCZYK      MARIA
# 946568         60  MECKLENBURG     1000597148  CW1335416   ZYWCZYK     MONICA
# 946569         60  MECKLENBURG     1000891545  CW1546413   ZYWICKI       CORY
# 946570         60  MECKLENBURG     1000863854  CW1528503   ZYWICKI     DANIEL
# 946571         60  MECKLENBURG     1000805149  CW1484561     ZYWNA    ZACHARY
#
# ...

# %%
charlotte_voter_hist
# Out:
#          county_id  county_desc  voter_reg_num election_lbl  \
# 19              60  MECKLENBURG      999856264   11/07/2023
# 26              60  MECKLENBURG      999870499   11/07/2023
# 36              60  MECKLENBURG     1000129811   11/07/2023
# 45              60  MECKLENBURG     1000149480   11/07/2023
# 97              60  MECKLENBURG      999892947   11/07/2023
# ...            ...          ...            ...          ...
# 3877855         60  MECKLENBURG     1000797433   11/07/2023
# 3877865         60  MECKLENBURG     1000797320   11/07/2023
# 3877898         60  MECKLENBURG     1000470410   11/07/2023
# 3878018         60  MECKLENBURG     1000747424   11/07/2023
# 3878092         60  MECKLENBURG     1000279263   11/07/2023
#
#                 election_desc           voting_method voted_party_cd  \
# 19       11/07/2023 MUNICIPAL        ABSENTEE ONESTOP            DEM
# 26       11/07/2023 MUNICIPAL  ELECTION DAY IN-PERSON            DEM
# ...

# %%
# Merge on Voter Registration Number
charlotte_voters_2023 = charlotte_voter_hist.merge(charlotte_vr, on='voter_reg_num')

# This dropped two voters, which probably isn't too concerning?

# %%
charlotte_voters_2023.columns
# Out:
# Index(['county_id_x', 'county_desc_x', 'voter_reg_num', 'election_lbl',
#        'election_desc', 'voting_method', 'voted_party_cd', 'voted_party_desc',
#        'pct_label', 'pct_description', 'ncid_x', 'voted_county_id',
#        'voted_county_desc', 'vtd_label', 'vtd_description', 'county_id_y',
#        'county_desc_y', 'ncid_y', 'last_name', 'first_name', 'middle_name',
#        'name_suffix_lbl', 'status_cd', 'voter_status_desc', 'reason_cd',
#        'voter_status_reason_desc', 'res_street_address', 'res_city_desc',
#        'state_cd', 'zip_code', 'mail_addr1', 'mail_addr2', 'mail_addr3',
#        'mail_addr4', 'mail_city', 'mail_state', 'mail_zipcode',
#        'full_phone_number', 'confidential_ind', 'registr_dt', 'race_code',
#        'ethnic_code', 'party_cd', 'gender_code', 'birth_year',
#        'age_at_year_end', 'birth_state', 'drivers_lic', 'precinct_abbrv',
#        'precinct_desc', 'municipality_abbrv', 'municipality_desc',
# ...

# %%
charlotte_voters_2023.columns
# Out:
# Index(['county_id_x', 'county_desc_x', 'voter_reg_num', 'election_lbl',
#        'election_desc', 'voting_method', 'voted_party_cd', 'voted_party_desc',
#        'pct_label', 'pct_description', 'ncid_x', 'voted_county_id',
#        'voted_county_desc', 'vtd_label', 'vtd_description', 'county_id_y',
#        'county_desc_y', 'ncid_y', 'last_name', 'first_name', 'middle_name',
#        'name_suffix_lbl', 'status_cd', 'voter_status_desc', 'reason_cd',
#        'voter_status_reason_desc', 'res_street_address', 'res_city_desc',
#        'state_cd', 'zip_code', 'mail_addr1', 'mail_addr2', 'mail_addr3',
#        'mail_addr4', 'mail_city', 'mail_state', 'mail_zipcode',
#        'full_phone_number', 'confidential_ind', 'registr_dt', 'race_code',
#        'ethnic_code', 'party_cd', 'gender_code', 'birth_year',
#        'age_at_year_end', 'birth_state', 'drivers_lic', 'precinct_abbrv',
#        'precinct_desc', 'municipality_abbrv', 'municipality_desc',
# ...

# %%
# need to sum based on party_cd to see percentage
party_cd = charlotte_voters_2023['party_cd'].value_counts(normalize=True) * 100
voted_cd = charlotte_voters_2023['voted_party_cd'].value_counts(normalize=True) * 100

# %%
party_cd
# Out:
# party_cd
# DEM    45.602989
# UNA    33.537338
# REP    20.604458
# LIB     0.239265
# GRE     0.015951
# Name: proportion, dtype: float64

# %%
import matplotlib

plot = party_cd.plot.pie(labels=charlotte_voters_2023['party_cd'], autopct='%1.1f%%', figsize=(7, 7))

# %%
plota = voted_cd.plot.pie(labels=charlotte_voters_2023['voted_party_cd'], autopct='%1.1f%%', figsize=(7, 7))
