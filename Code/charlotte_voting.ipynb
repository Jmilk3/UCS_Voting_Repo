# %%
import pandas as pd
from pathlib import Path
BASE_DIR = Path().resolve().parent

charlotte_mayor = pd.read_csv(BASE_DIR / "Election_Data_Sheets" / "csv" / "results_pct_20231107.csv")

# %%
charlotte_mayor = charlotte_mayor.loc[charlotte_mayor['County'] == "MECKLENBURG"]

# %%
charlotte_mayor = charlotte_mayor.loc[charlotte_mayor['Contest Name'] == "CITY OF CHARLOTTE MAYOR"]

# %%
charlotte_mayor
# Out:
#             County Election Date     Precinct  Contest Group ID Contest Type  \
# 2903   MECKLENBURG       11/7/23            1                 1            C
# 2904   MECKLENBURG       11/7/23            1                 1            C
# 2905   MECKLENBURG       11/7/23            1                 1            C
# 2906   MECKLENBURG       11/7/23            1                 1            C
# 2907   MECKLENBURG       11/7/23            1                 1            C
# ...            ...           ...          ...               ...          ...
# 31214  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31215  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31216  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31217  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
# 31218  MECKLENBURG       11/7/23  PROVISIONAL                 1            C
#
# ...

# %%
charlotte_vr = pd.read_csv(BASE_DIR / "Election_Data_Sheets" / "nc_data_2023.csv")

# %%
charlotte_vr =
# Out:
#       county_id.x county_desc.x  voter_reg_num.x election_lbl  \
# 0              51      JOHNSTON         33187370   11/07/2023
# 1              51      JOHNSTON         33067021   11/07/2023
# 2              51      JOHNSTON         33204631   11/07/2023
# 3              51      JOHNSTON         33083621   11/07/2023
# 4              51      JOHNSTON         33073420   11/07/2023
# ...           ...           ...              ...          ...
# 1191           51      JOHNSTON         33082769   11/07/2023
# 1192           51      JOHNSTON         33112148   11/07/2023
# 1193           51      JOHNSTON         33104303   11/07/2023
# 1194           51      JOHNSTON         33164013   11/07/2023
# 1195           51      JOHNSTON         33086516   11/07/2023
#
#              election_desc           voting_method voted_party_cd  \
# 0     11/07/2023 MUNICIPAL  ELECTION DAY IN-PERSON            DEM
# 1     11/07/2023 MUNICIPAL        ABSENTEE ONESTOP            DEM
# ...
