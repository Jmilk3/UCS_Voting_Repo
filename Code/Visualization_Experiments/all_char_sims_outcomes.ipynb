# %%
# Import the necessary packages
import pandas as pd
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from itertools import product, chain
BASE_DIR = Path().resolve().parent

# %%
# Create a string and list to read in all files.
start_title = ["charlotte_sims_"]
election_title = ["Charlotte Board of Education ", "Charlotte City Council ", "Charlotte Mayor "]
demographics = ["Bachelor's Degree", "Black", "High School Diploma", "Hispanic", "Some College", "White"]
end_title = ["_BT.csv", "_PL.csv", "_Cam.csv"]

# Find every possible combination, then join into list of strings
csv_list = list(product(start_title, election_title, demographics, end_title))
csv_titles = [[''.join(elem)] for elem in csv_list] # Source: https://stackoverflow.com/questions/72186008/python-join-strings-in-list-of-lists; https://stackoverflow.com/questions/11264684/flatten-list-of-lists
csv_titles = list(chain.from_iterable(csv_titles)) # Flatten into one list 
# Now we have a list of all the csvs we need to read-in and analyze!

# %%
# Read in all the csvs into a list of pandas dataframes
df_list = []

for i in csv_titles:
    df_list.append(pd.read_csv(BASE_DIR / "New_Simulation_Results" / "Elections" / "charlotte sims" / i))

# This code isn't currently running for Bachelor's Degree because of the difference between apostrophe and not. I just dropped it for now.

# %%
# Determine Plurality Winner

for i in range(len(df_list)):
    print(csv_titles[i])
    # Get plurality winner to set colors
    num_candidates = int(df_list[i]['Candidate'].isna().idxmax())
   
    df_list[i] = df_list[i].dropna().reset_index()
    grps = df_list[i].groupby(df_list[i].index // num_candidates)
    all_winners = []
    for _, dfg in grps:
        winners = dfg[dfg['Plurality Result'] == True]
        winners = winners['Candidate'] 
        all_winners.append(list(winners))

    all_winners = tuple(all_winners)

    counts = {}
    for j in all_winners:
        j = str(j)
        if j in counts:
            counts[j] += 1
        else:
            counts[j] = 1

    # Inspiration from: https://medium.com/@icodewithben/counting-and-graphing-categorical-data-with-matplotlib-017ac6d4aa73
    winners = list(counts.keys())
    values = list(counts.values())

    # Get overall winner
    plurality_winner = max(counts.items(), key=lambda item: item[1])

    print('plurality winner: ', plurality_winner)

    # Get ranked-choice winnner
    grps = df_list[i].groupby(df_list[i].index // num_candidates)
    all_winners = []
    for _, dfg in grps:
        winners = dfg[dfg['STV Result'] == True]
        winners = winners['Candidate'] 
        all_winners.append(list(winners))

    all_winners = tuple(all_winners)

    counts = {}
    for j in all_winners:
        j = str(j)
        if j in counts:
            counts[j] += 1
        else:
            counts[j] = 1

    # Inspiration from: https://medium.com/@icodewithben/counting-and-graphing-categorical-data-with-matplotlib-017ac6d4aa73
    winners = list(counts.keys())
    values = list(counts.values())

    # Get overall winner
    rcv_winner = max(counts)
    rcv_winner = max(counts.items(), key=lambda item: item[1])

    print('rcv winner: ', rcv_winner)
    # Now, assign colors based on plurality winner
    
    colors = ['plum' if i != plurality_winner[0] else 'mediumseagreen' for i in winners]

    fig, ax = plt.subplots()
    #ax.barh(winners, values, color = colors)
    ax.barh(counts.keys(), counts.values(), color = colors)
    for container in ax.containers:
        ax.bar_label(container)
    plt.xlabel('Number of Iterations')
    plt.title("Number of Iteration Wins for " + csv_titles[i])
# Out:
# char_sims_Charlotte Board of Education Black_BT.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 61)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 94)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 94, "['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']": 3, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 3}
# ['mediumseagreen', 'plum', 'plum']
# char_sims_Charlotte Board of Education Black_PL.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 66)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 95)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 95, "['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']": 3, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 2}
# ['mediumseagreen', 'plum', 'plum']
# char_sims_Charlotte Board of Education Black_Cam.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 78)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 54)
# {"['Claire Covington', 'Lenora Shipp', 'Liz Monterrey']": 3, "['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 54, "['Lenora Shipp', 'Liz Monterrey', 'Michael Johnson']": 39, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 3, "['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']": 1}
# ['plum', 'mediumseagreen', 'plum', 'plum', 'plum']
# char_sims_Charlotte Board of Education High School Diploma_BT.csv
# plurality winner:  ("['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']", 90)
# rcv winner:  ("['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']", 92)
# {"['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']": 92, "['Annette Albright', 'Lenora Shipp', 'Monty Witherspoon']": 8}
# ['mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education High School Diploma_PL.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 97)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 98)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 98, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 2}
# ['mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education High School Diploma_Cam.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 94)
# rcv winner:  ("['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']", 55)
# {"['Claire Covington', 'Lenora Shipp', 'Liz Monterrey']": 34, "['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']": 55, "['Claire Covington', 'Liz Monterrey', 'Monty Witherspoon']": 4, "['Bill Fountain', 'Liz Monterrey', 'Monty Witherspoon']": 4, "['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 3}
# ['plum', 'plum', 'plum', 'plum', 'mediumseagreen']
# char_sims_Charlotte Board of Education Hispanic_BT.csv
# plurality winner:  ("['Annette Albright', 'Lenora Shipp', 'Shamaiye Haynes']", 85)
# rcv winner:  ("['Annette Albright', 'Lenora Shipp', 'Shamaiye Haynes']", 95)
# {"['Annette Albright', 'Lenora Shipp', 'Shamaiye Haynes']": 95, "['Lenora Shipp', 'Michael Johnson', 'Shamaiye Haynes']": 5}
# ['mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education Hispanic_PL.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 94)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 99)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 99, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 1}
# ['mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education Hispanic_Cam.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 98)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 100)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Board of Education Some College_BT.csv
# plurality winner:  ("['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']", 84)
# rcv winner:  ("['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']", 90)
# {"['Lenora Shipp', 'Monty Witherspoon', 'Shamaiye Haynes']": 90, "['Lenora Shipp', 'Michael Johnson', 'Monty Witherspoon']": 1, "['Annette Albright', 'Lenora Shipp', 'Monty Witherspoon']": 9}
# ['mediumseagreen', 'plum', 'plum']
# char_sims_Charlotte Board of Education Some College_PL.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 87)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 94)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 94, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 6}
# ['mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education Some College_Cam.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 89)
# rcv winner:  ("['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']", 70)
# {"['Bill Fountain', 'Lenora Shipp', 'Liz Monterrey']": 70, "['Claire Covington', 'Lenora Shipp', 'Liz Monterrey']": 17, "['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 8, "['Bill Fountain', 'Liz Monterrey', 'Monty Witherspoon']": 5}
# ['plum', 'plum', 'mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education White_BT.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']", 68)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 60)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 60, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 39, "['Bill Fountain', 'Lenora Shipp', 'Monty Witherspoon']": 1}
# ['plum', 'mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education White_PL.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 65)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 94)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 94, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 6}
# ['mediumseagreen', 'plum']
# char_sims_Charlotte Board of Education White_Cam.csv
# plurality winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 76)
# rcv winner:  ("['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']", 83)
# {"['Lenora Shipp', 'Liz Monterrey', 'Monty Witherspoon']": 83, "['Lenora Shipp', 'Liz Monterrey', 'Michael Johnson']": 12, "['Claire Covington', 'Lenora Shipp', 'Liz Monterrey']": 3, "['Lenora Shipp', 'Liz Monterrey', 'Shamaiye Haynes']": 1, "['Liz Monterrey', 'Michael Johnson', 'Monty Witherspoon']": 1}
# ['mediumseagreen', 'plum', 'plum', 'plum', 'plum']
# char_sims_Charlotte City Council Black_BT.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Black_PL.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Black_Cam.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council High School Diploma_BT.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council High School Diploma_PL.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council High School Diploma_Cam.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Hispanic_BT.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# /var/folders/tx/qckl6gp57yq_ckc0ywsl5vlh0000gn/T/ipykernel_56866/550871108.py:68: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   fig, ax = plt.subplots()
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Hispanic_PL.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Hispanic_Cam.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Some College_BT.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Some College_PL.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council Some College_Cam.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council White_BT.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council White_PL.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte City Council White_Cam.csv
# plurality winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# rcv winner:  ("['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']", 100)
# {"['Dimple Ajmera', 'James (Smuggie) Mitchell', 'LaWana Slack-Mayfield', 'Victoria Watlington']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Black_BT.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Black_PL.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Black_Cam.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor High School Diploma_BT.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor High School Diploma_PL.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor High School Diploma_Cam.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Hispanic_BT.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Hispanic_PL.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Hispanic_Cam.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Some College_BT.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Some College_PL.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor Some College_Cam.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor White_BT.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor White_PL.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
# char_sims_Charlotte Mayor White_Cam.csv
# plurality winner:  ("['Vi Alexander Lyles']", 100)
# rcv winner:  ("['Vi Alexander Lyles']", 100)
# {"['Vi Alexander Lyles']": 100}
# ['mediumseagreen']
